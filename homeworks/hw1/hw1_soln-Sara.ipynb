# %% [markdown]
# #Homework 1 - Data Analysis and Regression
# In this assignment your challenge is to do some basic analysis for Airbnb. Provided in hw/data/ there are 2 data files, <a href=../data/bookings.csv>bookings.csv</a> and <a href=../data/listings.csv>listings.csv</a>. The objective is to practice data munging and begin our exploration of regression.

# %%
# Standard imports for data analysis packages in Python
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# This enables inline Plots
# %matplotlib inline

# Limit rows displayed in notebook
pd.set_option('display.max_rows', 50)
pd.set_option('display.precision', 2)

# %% [markdown]
# ##Part 1 - Data exploration
# ###First, create 2 data frames: `listings` and `bookings` from their respective data files

# %%
airbnb_listings = pd.read_csv('../data/listings.csv')
airbnb_bookings = pd.read_csv('../data/bookings.csv')

# %%
airbnb_listings.tail(5)
# Out:
#      prop_id        prop_type     neighborhood  price  person_capacity  \
# 403      404  Property type 2  Neighborhood 14    100                1
# 404      405  Property type 2  Neighborhood 13     85                2
# 405      406  Property type 1   Neighborhood 9     70                3
# 406      407  Property type 1  Neighborhood 13    129                2
# 407      408  Property type 1  Neighborhood 14    100                3
#
#      picture_count  description_length  tenure_months
# 403              8                 235              1
# 404             27                1048              1
# 405             18                 153              1
# 406             13                 370              1
# 407             21                 707              1

# %%
airbnb_listings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 408 entries, 0 to 407
# Data columns (total 8 columns):
# prop_id               408 non-null int64
# prop_type             408 non-null object
# neighborhood          408 non-null object
# price                 408 non-null int64
# person_capacity       408 non-null int64
# picture_count         408 non-null int64
# description_length    408 non-null int64
# tenure_months         408 non-null int64
# dtypes: int64(6), object(2)

# %% [markdown]
# ###What is the mean, median and standard deviation of price, person capacity, picture count, description length and tenure of the properties?

# %%
airbnb_listings.describe()
# Out:
#        prop_id   price  person_capacity  picture_count  description_length  \
# count    408.0   408.0            408.0          408.0               408.0
# mean     204.5   187.8              3.0           14.4               309.2
# std      117.9   353.1              1.6           10.5               228.0
# min        1.0    39.0              1.0            1.0                 0.0
# 25%      102.8    90.0              2.0            6.0               179.0
# 50%      204.5   125.0              2.0           12.0               250.0
# 75%      306.2   199.0              4.0           20.0               389.5
# max      408.0  5000.0             10.0           71.0              1969.0
#
#        tenure_months
# count          408.0
# mean             8.5
# std              5.9
# min              1.0
# 25%              4.0
# 50%              7.0
# 75%             13.0
# max             30.0

# %% [markdown]
# ###What what are the mean price, person capacity, picture count, description length and tenure of the properties grouped by property type?

# %%
airbnb_listings.groupby('prop_type')['price', 'person_capacity', 'picture_count', 'description_length', 'tenure_months'].agg('mean')
# Out:
#                  price  person_capacity  picture_count  description_length  \
# prop_type
# Property type 1  237.1              3.5           14.7               313.2
# Property type 2   93.3              2.0           13.9               304.9
# Property type 3   63.8              1.8            8.8               184.8
#
#                  tenure_months
# prop_type
# Property type 1            8.5
# Property type 2            8.4
# Property type 3           13.8

# %% [markdown]
# ###Same, but by property type per neighborhood?

# %%
airbnb_listings.groupby(['neighborhood', 'prop_type'])['price', 'person_capacity', 'picture_count', 'description_length', 'tenure_months'].agg('mean')
# Out:
#                                  price  person_capacity  picture_count  \
# neighborhood    prop_type
# Neighborhood 1  Property type 1   85.0              2.0           26.0
# Neighborhood 10 Property type 1  142.5              3.5           13.3
#                 Property type 2  137.5              2.0           20.0
# Neighborhood 11 Property type 1  159.4              3.2            9.9
#                 Property type 2   78.8              2.0           16.8
# ...                                ...              ...            ...
# Neighborhood 7  Property type 2  100.0              2.0            3.0
# Neighborhood 8  Property type 1  174.8              5.0           11.0
#                 Property type 2  350.0              4.0            5.0
# Neighborhood 9  Property type 1  151.1              4.3           13.4
#                 Property type 2  110.0              2.0            3.5
#
#                                  description_length  tenure_months
# neighborhood    prop_type
# Neighborhood 1  Property type 1               209.0            6.0
# Neighborhood 10 Property type 1               391.0            3.8
#                 Property type 2               126.0            3.5
# Neighborhood 11 Property type 1               379.0            9.6
#                 Property type 2               161.2           11.2
# ...                                             ...            ...
# Neighborhood 7  Property type 2               148.0            2.0
# Neighborhood 8  Property type 1               300.0            6.8
#                 Property type 2               223.0            3.0
# Neighborhood 9  Property type 1               471.4            5.7
#                 Property type 2               114.5            9.0
#
# [40 rows x 5 columns]

# %% [markdown]
# ###Plot daily bookings:

# %%
airbnb_bookings
# Out:
#       prop_id booking_date
# 0           9   2011-06-17
# 1          13   2011-08-12
# 2          21   2011-06-20
# 3          28   2011-05-05
# 4          29   2011-11-17
# 5          33   2011-12-06
# 6          61   2011-01-06
# 7          73   2011-11-04
# 8          82   2011-05-25
# 9          83   2011-05-18
# 10         89   2011-02-08
# 11        107   2011-02-16
# 12        111   2011-12-03
# 13        113   2011-03-13
# 14        121   2011-01-23
# 15        124   2011-03-03
# 16        135   2011-02-17
# 17        140   2011-05-21
# 18        143   2011-05-14
# 19        152   2011-07-21
# 20        157   2011-11-09
# 21        164   2011-04-03
# 22        177   2011-06-05
# 23        187   2011-10-15
# 24        188   2011-01-01
# ...       ...          ...
# 6051      408   2011-11-20
# 6052      408   2011-10-15
# 6053      408   2011-06-12
# 6054      408   2011-11-16
# 6055      408   2011-08-25
# 6056      408   2011-03-14
# 6057      408   2011-05-15
# 6058      408   2011-10-03
# 6059      408   2011-07-04
# 6060      408   2011-08-15
# 6061      408   2011-08-08
# 6062      408   2011-01-18
# 6063      408   2011-08-30
# 6064      408   2011-12-12
# 6065      408   2011-06-22
# 6066      408   2011-03-22
# 6067      408   2011-12-10
# 6068      408   2011-08-01
# 6069      408   2011-12-05
# 6070      408   2011-09-12
# 6071      408   2011-06-02
# 6072      408   2011-08-22
# 6073      408   2011-07-24
# 6074      408   2011-01-12
# 6075      408   2011-09-08
#
# [6076 rows x 2 columns]

# %%
airbnb_bookings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6076 entries, 0 to 6075
# Data columns (total 2 columns):
# prop_id         6076 non-null int64
# booking_date    6076 non-null object
# dtypes: int64(1), object(1)

# %%
airbnb_bookings.booking_date.value_counts().plot()

# %% [markdown]
# ###Plot the daily bookings per neighborhood (provide a legend)

# %% [markdown]
# ##Part 2 - Develop a data set

# %% [markdown]
# ###Add the columns `number_of_bookings` and `booking_rate` (number_of_bookings/tenure_months) to your `listings` data frame

# %% [markdown]
# ###We only want to analyze well established properties, so let's filter out any properties that have a tenure less than 10 months

# %% [markdown]
# ###`prop_type` and `neighborhood` are categorical variables, use `get_dummies()` (http://pandas.pydata.org/pandas-docs/stable/generated/pandas.core.reshape.get_dummies.html) to transform this column of categorical data to many columns of boolean values (after applying this function correctly there should be 1 column for every prop_type and 1 column for every neighborhood category.

# %% [markdown]
# ###create test and training sets for your regressors and predictors
# predictor (y) is `booking_rate`, regressors (X) are everything else, except `prop_id`,`booking_rate`,`prop_type`,`neighborhood` and `number_of_bookings`<br>
# http://scikit-learn.org/stable/modules/generated/sklearn.cross_validation.train_test_split.html<br>
# http://pandas.pydata.org/pandas-docs/stable/basics.html#dropping-labels-from-an-axis

# %%
from sklearn.cross_validation import train_test_split

# %% [markdown]
# ##Part 3 - Model `booking_rate`

# %% [markdown]
# ###Create a linear regression model of your listings

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()

# %% [markdown]
# ###fit your model with your test sets

# %% [markdown]
# ###report the score
# http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LinearRegression.html#sklearn.linear_model.LinearRegression.score

# %% [markdown]
# ###Interpret the results of the above model:
# * What does the `score` method do?
# * What does this tell us about our model?

# %% [markdown]
# ...type here...

# %% [markdown]
# ##Optional - Iterate
# Create an alternative predictor (e.g. monthly revenue) and use the same modeling pattern in Part 3 to
